# %% [markdown]
# Задача 1. Что выведет этот код?
# import pandas as pd
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
# print(df.loc[1, 'B'])
# print(df.iloc[1, 0])

# %% [markdown]
# 5
# 2

# %% [markdown]
# Задача 2. Какой будет результат?
# data = {'x': [10, 20, 30], 'y': [1, 2, 3]}
# df = pd.DataFrame(data)
# df['z'] = df['x'] > 15
# print(df['z'].sum())

# %%
2
